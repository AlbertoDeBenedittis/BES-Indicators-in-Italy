# %% [markdown]
# # SetUp

# %%
import geopandas as gpd
import pandas as pd

# %%
import os

# %% [markdown]
# What we want to achieve now is :
# to merge the dataset with the BES indicators'data with their respective geodataframes.

# %%
Lim_Path_Prov = 'E:\Geospatial_Project\Dati\Limiti\Lim\ProvCM01012021\ProvCM01012021_WGS84.shp'
Geo_Prov = gpd.read_file(Lim_Path_Prov)

# %%
Lim_Path_Reg = 'E:\Geospatial_Project\Dati\Limiti\Lim\Reg01012021\Reg01012021_WGS84.shp'
Geo_Reg = gpd.read_file(Lim_Path_Reg)

# %%
Lim_Path_Macro = 'E:\Geospatial_Project\Dati\Limiti\Lim\RipGeo01012021\RipGeo01012021_WGS84.shp'
Geo_Macro = gpd.read_file(Lim_Path_Macro)

# %%
Geo_Macro
# Out:
#    COD_RIP     DEN_RIP    Shape_Leng    Shape_Area  \
# 0        1  Nord-Ovest  2.670894e+06  5.792680e+10
# 1        2    Nord-Est  2.556416e+06  6.232712e+10
# 2        3      Centro  2.413965e+06  5.808457e+10
# 3        4         Sud  3.118909e+06  7.379777e+10
# 4        5       Isole  3.872902e+06  4.993200e+10
#
#                                             geometry
# 0  MULTIPOLYGON (((568230.816 4874870.697, 568232...
# 1  MULTIPOLYGON (((618335.211 4893983.160, 618329...
# 2  MULTIPOLYGON (((875819.121 4525280.544, 875832...
# 3  MULTIPOLYGON (((1083350.847 4416684.239, 10833...
# 4  MULTIPOLYGON (((822859.631 3935387.330, 822886...

# %%
len(Geo_Prov) + len(Geo_Macro) + len(Geo_Reg)
# Out:
# 132

# %%
Geo_Reg
# Out:
#     COD_RIP  COD_REG                DEN_REG    Shape_Leng    Shape_Area  \
# 0         1        1               Piemonte  1.333428e+06  2.538670e+10
# 1         1        2          Valle d'Aosta  3.258364e+05  3.260854e+09
# 2         1        3              Lombardia  1.511132e+06  2.386310e+10
# 3         2        4    Trentino-Alto Adige  8.598731e+05  1.360472e+10
# 4         2        5                 Veneto  1.140433e+06  1.834537e+10
# 5         2        6  Friuli Venezia Giulia  7.692437e+05  7.932482e+09
# 6         1        7                Liguria  1.079642e+06  5.416152e+09
# 7         2        8         Emilia-Romagna  1.282028e+06  2.244454e+10
# 8         3        9                Toscana  1.552065e+06  2.298744e+10
# 9         3       10                 Umbria  6.714160e+05  8.464223e+09
# 10        3       11                 Marche  7.110915e+05  9.401183e+09
# 11        3       12                  Lazio  1.201765e+06  1.723172e+10
# ...
